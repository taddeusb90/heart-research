# %% [markdown]
# # Heart Experiment: 3D Point Cloud Analysis
#
# In this notebook, we will:
#
# 1. **Load** multiple PLY point cloud files (in batches of 100 to avoid excessive memory usage).
# 2. **Create** a Pandas DataFrame for each point cloud.
# 3. **Compute** a frame-to-frame difference (delta) for each point in each coordinate (`x`, `y`, `z`).
# 4. **Visualize** the time series of changes.
#
# **Important Note**
# This example assumes that each row (point) in the point cloud at time `t` corresponds to the *same physical point* at time `t-1`. In many real-world scenarios, the number and order of points may differ between consecutive frames. Proper alignment and correspondence would require additional steps (e.g., using nearest neighbors, point cloud registration, or other tracking methods). For this simple demonstration, we proceed under the assumption that row `i` in frame `t` corresponds to row `i` in frame `t-1`.

# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Optional: If you want to use open3d to read ply files:
# !pip install open3d
try:
    import open3d as o3d
    USE_OPEN3D = True
except ImportError:
    USE_OPEN3D = False

# For plotting in Jupyter
# %matplotlib inline

# %% [markdown]
# **Explanation**:
# - We import `os` and `glob` to help with file paths.
# - We import `numpy` and `pandas` for data handling.
# - We import `matplotlib.pyplot` for plotting.
# - We optionally import `open3d` if available for convenient PLY file reading. Otherwise, we will write a custom PLY reader.

# %% [markdown]
# ## 2. Define a Function to Read a Single PLY File

# %%
def read_ply_as_dataframe(ply_path):
    """
    Reads an ASCII PLY file and returns a DataFrame containing 
    the columns: ['x', 'y', 'z', 'nx', 'ny', 'nz'].
    """
    if USE_OPEN3D:
        # Use open3d for convenience
        pcd = o3d.io.read_point_cloud(ply_path)
        points = np.asarray(pcd.points)
        if pcd.has_normals():
            normals = np.asarray(pcd.normals)
        else:
            normals = np.zeros_like(points)
        data = np.hstack([points, normals])
    else:
        # Fallback: manual parsing of ASCII PLY
        data_lines = []
        with open(ply_path, 'r') as f:
            header_ended = False
            for line in f:
                if header_ended:
                    values = line.strip().split()
                    if len(values) == 6:
                        data_lines.append([float(v) for v in values])
                if line.strip() == "end_header":
                    header_ended = True
        data = np.array(data_lines, dtype=np.float32)
    
    return pd.DataFrame(data, columns=["x", "y", "z", "nx", "ny", "nz"])

# %% [markdown]
# **Explanation**:
# - If `open3d` is available, we use `read_point_cloud` to read the file.
# - Otherwise, we manually read the ASCII PLY, skip the header until `end_header`, then parse each line as floats.
# - We then create a Pandas DataFrame with the columns `["x", "y", "z", "nx", "ny", "nz"]`.

# %% [markdown]
# ## 3. Sliding Window Over Point Cloud Files

# %%
def get_ply_file_paths(data_dir):
    """
    Returns a sorted list of .ply files from the given data directory 
    (including nested subdirectories).
    """
    ply_files = glob.glob(os.path.join(data_dir, "**", "*.ply"), recursive=True)
    ply_files.sort()
    return ply_files

def sliding_window_ply_files(ply_files, window_size=100):
    """
    Generator that yields chunks of up to 'window_size' .ply file paths at a time.
    """
    for i in range(0, len(ply_files), window_size):
        yield ply_files[i:i+window_size]

# %% [markdown]
# **Explanation**:
# - `get_ply_file_paths` collects all PLY files in the directory (and subdirectories) using `glob` and sorts them.
# - `sliding_window_ply_files` is a generator that splits the list of files into chunks of size 100 (by default). This approach helps avoid loading all files into memory at once.

# %% [markdown]
# ## 4. Computing Frame-to-Frame Differences

# %%
def compute_pointcloud_deltas(ply_file_chunk):
    """
    Given a list of PLY file paths (a chunk),
    read them in order, store each as a DataFrame,
    then compute the difference (delta) between consecutive frames.
    
    Returns:
        frames: list of DataFrames (each containing x,y,z,nx,ny,nz)
        deltas: list of DataFrames (each containing delta_x, delta_y, delta_z, delta_nx, delta_ny, delta_nz)
    """
    frames = []
    deltas = []
    
    prev_df = None
    for idx, ply_path in enumerate(ply_file_chunk):
        df = read_ply_as_dataframe(ply_path)
        frames.append(df)
        
        if prev_df is not None:
            # Ensure both DataFrames have the same number of rows
            if len(df) == len(prev_df):
                delta_df = df[["x", "y", "z", "nx", "ny", "nz"]] - prev_df[["x", "y", "z", "nx", "ny", "nz"]]
                delta_df.columns = ["delta_x", "delta_y", "delta_z", "delta_nx", "delta_ny", "delta_nz"]
                deltas.append(delta_df)
            else:
                print(f"Warning: Different number of points between {ply_file_chunk[idx-1]} and {ply_path}")
                row_count = min(len(df), len(prev_df))
                delta_array = np.full((row_count, 6), np.nan)
                delta_df = pd.DataFrame(delta_array, columns=["delta_x", "delta_y", "delta_z", "delta_nx", "delta_ny", "delta_nz"])
                deltas.append(delta_df)
        prev_df = df
    
    return frames, deltas

# %% [markdown]
# **Explanation**:
# 1. We loop through each PLY file in the chunk.
# 2. We read its contents into a DataFrame.
# 3. We subtract the *previous* DataFrame from the *current* DataFrame if the row counts match (computing `delta_x`, `delta_y`, `delta_z`, etc.).
# 4. We store both the original frames and the deltas.
#
# **Note**: If the number of points differ between consecutive frames, we show a warning and (in this example) fill the deltas with `NaN` for the overlapping set of points. You may need a more sophisticated approach depending on your data.

# %% [markdown]
# ## 5. End-to-End Example

# %%
# Example usage (uncomment and adjust path as needed):
data_directory = "./data"
all_ply_files = get_ply_file_paths(data_directory)

# For demonstration, we'll assume you have enough PLY files to form multiple chunks.

# If you'd like to accumulate ALL deltas (for a specific coordinate) across ALL chunks 
# into a single list and plot them on one line plot, here's how:

# all_delta_x = []  # If you only care about x
# Or for all 6 deltas (delta_x, delta_y, delta_z, delta_nx, delta_ny, delta_nz):
all_deltas = {
    "delta_x": [],
    "delta_y": [],
    "delta_z": [],
    "delta_nx": [],
    "delta_ny": [],
    "delta_nz": []
}

for chunk_idx, ply_chunk in enumerate(sliding_window_ply_files(all_ply_files, window_size=100)):
    frames, deltas = compute_pointcloud_deltas(ply_chunk)
    
    # 'deltas' is a list of DataFrames for consecutive differences between frames in this chunk
    for delta_df in deltas:
        # Accumulate each delta column
        all_deltas["delta_x"].extend(delta_df["delta_x"].values.tolist())
        all_deltas["delta_y"].extend(delta_df["delta_y"].values.tolist())
        all_deltas["delta_z"].extend(delta_df["delta_z"].values.tolist())
        all_deltas["delta_nx"].extend(delta_df["delta_nx"].values.tolist())
        all_deltas["delta_ny"].extend(delta_df["delta_ny"].values.tolist())
        all_deltas["delta_nz"].extend(delta_df["delta_nz"].values.tolist())

# After processing all chunks, we can plot them in one chart (lines only):
plt.figure(figsize=(12,6))
plt.plot(all_deltas["delta_x"], label="Delta X")
plt.plot(all_deltas["delta_y"], label="Delta Y")
plt.plot(all_deltas["delta_z"], label="Delta Z")
plt.plot(all_deltas["delta_nx"], label="Delta NX")
plt.plot(all_deltas["delta_ny"], label="Delta NY")
plt.plot(all_deltas["delta_nz"], label="Delta NZ")
plt.title("All Point Cloud Deltas Across All Chunks")
plt.xlabel("Frame-to-Frame Index (accumulated)")
plt.ylabel("Delta Value")
plt.legend()
plt.show()
# Out:
# Warning: Different number of points between ./data/1742119254128/cloud_260167.ply and ./data/1742119254128/cloud_260225.ply
# Warning: Different number of points between ./data/1742119254128/cloud_260225.ply and ./data/1742119254128/cloud_260284.ply
# Warning: Different number of points between ./data/1742119254128/cloud_260284.ply and ./data/1742119254128/cloud_260342.ply
# Warning: Different number of points between ./data/1742119254128/cloud_260342.ply and ./data/1742119254128/cloud_260400.ply
# Warning: Different number of points between ./data/1742119254128/cloud_260400.ply and ./data/1742119254128/cloud_260458.ply
# Warning: Different number of points between ./data/1742119254128/cloud_260458.ply and ./data/1742119254128/cloud_260517.ply
# Warning: Different number of points between ./data/1742119254128/cloud_260517.ply and ./data/1742119254128/cloud_260575.ply
# Warning: Different number of points between ./data/1742119254128/cloud_260575.ply and ./data/1742119254128/cloud_260633.ply
# Warning: Different number of points between ./data/1742119254128/cloud_260633.ply and ./data/1742119254128/cloud_260691.ply
# Warning: Different number of points between ./data/1742119254128/cloud_260691.ply and ./data/1742119254128/cloud_260750.ply
# Warning: Different number of points between ./data/1742119254128/cloud_260750.ply and ./data/1742119254128/cloud_260808.ply
# Warning: Different number of points between ./data/1742119254128/cloud_260808.ply and ./data/1742119254128/cloud_260866.ply
# Warning: Different number of points between ./data/1742119254128/cloud_260866.ply and ./data/1742119254128/cloud_260924.ply
# Warning: Different number of points between ./data/1742119254128/cloud_260924.ply and ./data/1742119254128/cloud_260983.ply
# Warning: Different number of points between ./data/1742119254128/cloud_260983.ply and ./data/1742119254128/cloud_261041.ply
# Warning: Different number of points between ./data/1742119254128/cloud_261041.ply and ./data/1742119254128/cloud_261099.ply
# Warning: Different number of points between ./data/1742119254128/cloud_261099.ply and ./data/1742119254128/cloud_261157.ply
# Warning: Different number of points between ./data/1742119254128/cloud_261157.ply and ./data/1742119254128/cloud_261216.ply
# Warning: Different number of points between ./data/1742119254128/cloud_261216.ply and ./data/1742119254128/cloud_261274.ply
# Warning: Different number of points between ./data/1742119254128/cloud_261274.ply and ./data/1742119254128/cloud_261332.ply
# Warning: Different number of points between ./data/1742119254128/cloud_261332.ply and ./data/1742119254128/cloud_261390.ply
# Warning: Different number of points between ./data/1742119254128/cloud_261390.ply and ./data/1742119254128/cloud_261449.ply
# Warning: Different number of points between ./data/1742119254128/cloud_261449.ply and ./data/1742119254128/cloud_261507.ply
# Warning: Different number of points between ./data/1742119254128/cloud_261507.ply and ./data/1742119254128/cloud_261565.ply
# Warning: Different number of points between ./data/1742119254128/cloud_261565.ply and ./data/1742119254128/cloud_261623.ply
# Warning: Different number of points between ./data/1742119254128/cloud_261623.ply and ./data/1742119254128/cloud_261682.ply
# Warning: Different number of points between ./data/1742119254128/cloud_261682.ply and ./data/1742119254128/cloud_261740.ply
# Warning: Different number of points between ./data/1742119254128/cloud_261740.ply and ./data/1742119254128/cloud_261798.ply
# Warning: Different number of points between ./data/1742119254128/cloud_261798.ply and ./data/1742119254128/cloud_261856.ply
# Warning: Different number of points between ./data/1742119254128/cloud_261856.ply and ./data/1742119254128/cloud_261915.ply
# Warning: Different number of points between ./data/1742119254128/cloud_261915.ply and ./data/1742119254128/cloud_261973.ply
# Warning: Different number of points between ./data/1742119254128/cloud_261973.ply and ./data/1742119254128/cloud_262031.ply
# Warning: Different number of points between ./data/1742119254128/cloud_262031.ply and ./data/1742119254128/cloud_262090.ply
# Warning: Different number of points between ./data/1742119254128/cloud_262090.ply and ./data/1742119254128/cloud_262148.ply
# Warning: Different number of points between ./data/1742119254128/cloud_262148.ply and ./data/1742119254128/cloud_262206.ply
# Warning: Different number of points between ./data/1742119254128/cloud_262206.ply and ./data/1742119254128/cloud_262264.ply
# Warning: Different number of points between ./data/1742119254128/cloud_262264.ply and ./data/1742119254128/cloud_262323.ply
# Warning: Different number of points between ./data/1742119254128/cloud_262323.ply and ./data/1742119254128/cloud_262381.ply
# Warning: Different number of points between ./data/1742119254128/cloud_262381.ply and ./data/1742119254128/cloud_262439.ply
# Warning: Different number of points between ./data/1742119254128/cloud_262439.ply and ./data/1742119254128/cloud_262497.ply
# Warning: Different number of points between ./data/1742119254128/cloud_262497.ply and ./data/1742119254128/cloud_262556.ply
# Warning: Different number of points between ./data/1742119254128/cloud_262556.ply and ./data/1742119254128/cloud_262614.ply
# Warning: Different number of points between ./data/1742119254128/cloud_262614.ply and ./data/1742119254128/cloud_262672.ply
# Warning: Different number of points between ./data/1742119254128/cloud_262672.ply and ./data/1742119254128/cloud_262730.ply
# Warning: Different number of points between ./data/1742119254128/cloud_262730.ply and ./data/1742119254128/cloud_262789.ply
# Warning: Different number of points between ./data/1742119254128/cloud_262789.ply and ./data/1742119254128/cloud_262847.ply
# Warning: Different number of points between ./data/1742119254128/cloud_262847.ply and ./data/1742119254128/cloud_262905.ply
# Warning: Different number of points between ./data/1742119254128/cloud_262905.ply and ./data/1742119254128/cloud_262963.ply
# Warning: Different number of points between ./data/1742119254128/cloud_262963.ply and ./data/1742119254128/cloud_263022.ply
# Warning: Different number of points between ./data/1742119254128/cloud_263022.ply and ./data/1742119254128/cloud_263080.ply
# Warning: Different number of points between ./data/1742119254128/cloud_263080.ply and ./data/1742119254128/cloud_263138.ply
# Warning: Different number of points between ./data/1742119254128/cloud_263138.ply and ./data/1742119254128/cloud_263196.ply
# Warning: Different number of points between ./data/1742119254128/cloud_263196.ply and ./data/1742119254128/cloud_263255.ply
# Warning: Different number of points between ./data/1742119254128/cloud_263255.ply and ./data/1742119254128/cloud_263313.ply
# Warning: Different number of points between ./data/1742119254128/cloud_263371.ply and ./data/1742119254128/cloud_263429.ply
# Warning: Different number of points between ./data/1742119254128/cloud_263429.ply and ./data/1742119254128/cloud_263488.ply
# Warning: Different number of points between ./data/1742119254128/cloud_263488.ply and ./data/1742119254128/cloud_263546.ply
# Warning: Different number of points between ./data/1742119254128/cloud_263546.ply and ./data/1742119254128/cloud_263604.ply
# Warning: Different number of points between ./data/1742119254128/cloud_263604.ply and ./data/1742119254128/cloud_263662.ply
# Warning: Different number of points between ./data/1742119254128/cloud_263662.ply and ./data/1742119254128/cloud_263721.ply
# Warning: Different number of points between ./data/1742119254128/cloud_263721.ply and ./data/1742119254128/cloud_263779.ply
# Warning: Different number of points between ./data/1742119254128/cloud_263779.ply and ./data/1742119254128/cloud_263837.ply
# Warning: Different number of points between ./data/1742119254128/cloud_263837.ply and ./data/1742119254128/cloud_263896.ply
# Warning: Different number of points between ./data/1742119254128/cloud_263896.ply and ./data/1742119254128/cloud_263954.ply
# Warning: Different number of points between ./data/1742119254128/cloud_263954.ply and ./data/1742119254128/cloud_264012.ply
# Warning: Different number of points between ./data/1742119254128/cloud_264012.ply and ./data/1742119254128/cloud_264070.ply
# Warning: Different number of points between ./data/1742119254128/cloud_264070.ply and ./data/1742119254128/cloud_264129.ply
# Warning: Different number of points between ./data/1742119254128/cloud_264129.ply and ./data/1742119254128/cloud_264187.ply
# Warning: Different number of points between ./data/1742119254128/cloud_264187.ply and ./data/1742119254128/cloud_264245.ply
# Warning: Different number of points between ./data/1742119254128/cloud_264245.ply and ./data/1742119254128/cloud_264303.ply
# Warning: Different number of points between ./data/1742119254128/cloud_264303.ply and ./data/1742119254128/cloud_264362.ply
# Warning: Different number of points between ./data/1742119254128/cloud_264362.ply and ./data/1742119254128/cloud_264420.ply
# Warning: Different number of points between ./data/1742119254128/cloud_264420.ply and ./data/1742119254128/cloud_264478.ply
# Warning: Different number of points between ./data/1742119254128/cloud_264478.ply and ./data/1742119254128/cloud_264536.ply
# Warning: Different number of points between ./data/1742119254128/cloud_264536.ply and ./data/1742119254128/cloud_264595.ply
# Warning: Different number of points between ./data/1742119254128/cloud_264595.ply and ./data/1742119254128/cloud_264653.ply
# Warning: Different number of points between ./data/1742119254128/cloud_264653.ply and ./data/1742119254128/cloud_264711.ply
# Warning: Different number of points between ./data/1742119254128/cloud_264711.ply and ./data/1742119254128/cloud_264769.ply
# Warning: Different number of points between ./data/1742119254128/cloud_264769.ply and ./data/1742119254128/cloud_264828.ply
# Warning: Different number of points between ./data/1742119254128/cloud_264828.ply and ./data/1742119254128/cloud_264886.ply
# Warning: Different number of points between ./data/1742119254128/cloud_264886.ply and ./data/1742119254128/cloud_264944.ply
# Warning: Different number of points between ./data/1742119254128/cloud_264944.ply and ./data/1742119254128/cloud_265002.ply
# Warning: Different number of points between ./data/1742119254128/cloud_265002.ply and ./data/1742119254128/cloud_265061.ply
# Warning: Different number of points between ./data/1742119254128/cloud_265061.ply and ./data/1742119254128/cloud_265119.ply
# Warning: Different number of points between ./data/1742119254128/cloud_265119.ply and ./data/1742119254128/cloud_265177.ply
# Warning: Different number of points between ./data/1742119254128/cloud_265177.ply and ./data/1742119254128/cloud_265235.ply
# Warning: Different number of points between ./data/1742119254128/cloud_265235.ply and ./data/1742119254128/cloud_265294.ply
# Warning: Different number of points between ./data/1742119254128/cloud_265294.ply and ./data/1742119254128/cloud_265352.ply
# Warning: Different number of points between ./data/1742119254128/cloud_265352.ply and ./data/1742119254128/cloud_265410.ply
# Warning: Different number of points between ./data/1742119254128/cloud_265410.ply and ./data/1742119254128/cloud_265468.ply
# Warning: Different number of points between ./data/1742119254128/cloud_265527.ply and ./data/1742119254128/cloud_265585.ply
# Warning: Different number of points between ./data/1742119254128/cloud_265585.ply and ./data/1742119254128/cloud_265643.ply
# Warning: Different number of points between ./data/1742119254128/cloud_265643.ply and ./data/1742119254128/cloud_265701.ply
# Warning: Different number of points between ./data/1742119254128/cloud_265701.ply and ./data/1742119254128/cloud_265760.ply
# Warning: Different number of points between ./data/1742119254128/cloud_265760.ply and ./data/1742119254128/cloud_265818.ply
# Warning: Different number of points between ./data/1742119254128/cloud_265818.ply and ./data/1742119254128/cloud_265876.ply
# Warning: Different number of points between ./data/1742119254128/cloud_265876.ply and ./data/1742119254128/cloud_265935.ply
# Warning: Different number of points between ./data/1742119254128/cloud_265993.ply and ./data/1742119254128/cloud_266051.ply
# Warning: Different number of points between ./data/1742119254128/cloud_266051.ply and ./data/1742119254128/cloud_266109.ply
# Warning: Different number of points between ./data/1742119254128/cloud_266109.ply and ./data/1742119254128/cloud_266168.ply
# Warning: Different number of points between ./data/1742119254128/cloud_266168.ply and ./data/1742119254128/cloud_266226.ply
# Warning: Different number of points between ./data/1742119254128/cloud_266226.ply and ./data/1742119254128/cloud_266284.ply
# Warning: Different number of points between ./data/1742119254128/cloud_266284.ply and ./data/1742119254128/cloud_266342.ply
# Warning: Different number of points between ./data/1742119254128/cloud_266342.ply and ./data/1742119254128/cloud_266401.ply
# Warning: Different number of points between ./data/1742119254128/cloud_266401.ply and ./data/1742119254128/cloud_266459.ply
# Warning: Different number of points between ./data/1742119254128/cloud_266459.ply and ./data/1742119254128/cloud_266517.ply
# Warning: Different number of points between ./data/1742119254128/cloud_266517.ply and ./data/1742119254128/cloud_266575.ply
# Warning: Different number of points between ./data/1742119254128/cloud_266575.ply and ./data/1742119254128/cloud_266634.ply
# Warning: Different number of points between ./data/1742119254128/cloud_266634.ply and ./data/1742119254128/cloud_266692.ply
# Warning: Different number of points between ./data/1742119254128/cloud_266692.ply and ./data/1742119254128/cloud_266750.ply
# Warning: Different number of points between ./data/1742119254128/cloud_266750.ply and ./data/1742119254128/cloud_266808.ply
# Warning: Different number of points between ./data/1742119254128/cloud_266808.ply and ./data/1742119254128/cloud_266867.ply
# Warning: Different number of points between ./data/1742119254128/cloud_266867.ply and ./data/1742119254128/cloud_266925.ply
# Warning: Different number of points between ./data/1742119254128/cloud_266925.ply and ./data/1742119254128/cloud_266983.ply
# Warning: Different number of points between ./data/1742119254128/cloud_266983.ply and ./data/1742119254128/cloud_267041.ply
# Warning: Different number of points between ./data/1742119254128/cloud_267041.ply and ./data/1742119254128/cloud_267100.ply
# Warning: Different number of points between ./data/1742119254128/cloud_267158.ply and ./data/1742119254128/cloud_267216.ply
# Warning: Different number of points between ./data/1742119254128/cloud_267216.ply and ./data/1742119254128/cloud_267274.ply
# Warning: Different number of points between ./data/1742119254128/cloud_267274.ply and ./data/1742119254128/cloud_267333.ply
# Warning: Different number of points between ./data/1742119254128/cloud_267333.ply and ./data/1742119254128/cloud_267391.ply
# Warning: Different number of points between ./data/1742119254128/cloud_267449.ply and ./data/1742119254128/cloud_267507.ply
# Warning: Different number of points between ./data/1742119254128/cloud_267507.ply and ./data/1742119254128/cloud_267566.ply
# Warning: Different number of points between ./data/1742119254128/cloud_267566.ply and ./data/1742119254128/cloud_267624.ply
# Warning: Different number of points between ./data/1742119254128/cloud_267624.ply and ./data/1742119254128/cloud_267682.ply
# Warning: Different number of points between ./data/1742119254128/cloud_267682.ply and ./data/1742119254128/cloud_267740.ply
# Warning: Different number of points between ./data/1742119254128/cloud_267740.ply and ./data/1742119254128/cloud_267799.ply
# Warning: Different number of points between ./data/1742119254128/cloud_267799.ply and ./data/1742131588782/cloud_222369.ply
# Warning: Different number of points between ./data/1742131588782/cloud_232505.ply and ./data/1742133879843/cloud_1000025.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1000083.ply and ./data/1742133879843/cloud_1000142.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1000142.ply and ./data/1742133879843/cloud_1000200.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1000200.ply and ./data/1742133879843/cloud_1000258.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1000316.ply and ./data/1742133879843/cloud_1000375.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1000375.ply and ./data/1742133879843/cloud_1000433.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1000549.ply and ./data/1742133879843/cloud_1000608.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1000608.ply and ./data/1742133879843/cloud_1000666.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1000782.ply and ./data/1742133879843/cloud_1000841.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1000841.ply and ./data/1742133879843/cloud_1000899.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1000899.ply and ./data/1742133879843/cloud_1000957.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1001423.ply and ./data/1742133879843/cloud_1001482.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1001598.ply and ./data/1742133879843/cloud_1001656.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1001715.ply and ./data/1742133879843/cloud_1001773.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1001948.ply and ./data/1742133879843/cloud_1002006.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1002006.ply and ./data/1742133879843/cloud_1002064.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1002064.ply and ./data/1742133879843/cloud_1002122.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1002181.ply and ./data/1742133879843/cloud_1002239.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1002297.ply and ./data/1742133879843/cloud_1002355.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1002414.ply and ./data/1742133879843/cloud_1002472.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1002472.ply and ./data/1742133879843/cloud_1002530.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1002530.ply and ./data/1742133879843/cloud_1002588.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1002588.ply and ./data/1742133879843/cloud_1002647.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1002647.ply and ./data/1742133879843/cloud_1002705.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1002763.ply and ./data/1742133879843/cloud_1002821.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1002821.ply and ./data/1742133879843/cloud_1002880.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1002996.ply and ./data/1742133879843/cloud_1003054.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1003113.ply and ./data/1742133879843/cloud_1003171.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1003229.ply and ./data/1742133879843/cloud_1003287.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1003287.ply and ./data/1742133879843/cloud_1003346.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1003462.ply and ./data/1742133879843/cloud_1003521.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1003521.ply and ./data/1742133879843/cloud_1003579.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1003579.ply and ./data/1742133879843/cloud_1003637.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1003637.ply and ./data/1742133879843/cloud_1003695.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1003695.ply and ./data/1742133879843/cloud_1003754.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1003754.ply and ./data/1742133879843/cloud_1003812.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1003812.ply and ./data/1742133879843/cloud_1003870.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1003870.ply and ./data/1742133879843/cloud_1003928.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1003928.ply and ./data/1742133879843/cloud_1003987.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1003987.ply and ./data/1742133879843/cloud_1004045.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1004045.ply and ./data/1742133879843/cloud_1004103.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1004103.ply and ./data/1742133879843/cloud_1004161.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1004161.ply and ./data/1742133879843/cloud_1004220.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1004220.ply and ./data/1742133879843/cloud_1004278.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1004278.ply and ./data/1742133879843/cloud_1004336.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1004336.ply and ./data/1742133879843/cloud_1004394.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1004394.ply and ./data/1742133879843/cloud_1004453.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1004453.ply and ./data/1742133879843/cloud_1004511.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1004511.ply and ./data/1742133879843/cloud_1004569.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1004569.ply and ./data/1742133879843/cloud_1004627.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1004627.ply and ./data/1742133879843/cloud_1004686.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1004686.ply and ./data/1742133879843/cloud_1004744.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1004744.ply and ./data/1742133879843/cloud_1004802.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1004802.ply and ./data/1742133879843/cloud_1004860.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1004860.ply and ./data/1742133879843/cloud_1004919.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1004919.ply and ./data/1742133879843/cloud_1004977.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1004977.ply and ./data/1742133879843/cloud_1005035.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1005035.ply and ./data/1742133879843/cloud_1005093.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1005093.ply and ./data/1742133879843/cloud_1005152.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1005152.ply and ./data/1742133879843/cloud_1005210.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1005210.ply and ./data/1742133879843/cloud_1005268.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1005268.ply and ./data/1742133879843/cloud_1005326.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1005326.ply and ./data/1742133879843/cloud_1005385.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1005501.ply and ./data/1742133879843/cloud_1005560.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1005560.ply and ./data/1742133879843/cloud_1005618.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1005618.ply and ./data/1742133879843/cloud_1005676.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1005676.ply and ./data/1742133879843/cloud_1005734.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1005734.ply and ./data/1742133879843/cloud_1005793.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1005793.ply and ./data/1742133879843/cloud_1005851.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1005851.ply and ./data/1742133879843/cloud_1005909.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1005909.ply and ./data/1742133879843/cloud_1005967.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1005967.ply and ./data/1742133879843/cloud_1006026.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1006026.ply and ./data/1742133879843/cloud_1006084.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1006084.ply and ./data/1742133879843/cloud_1006142.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1006142.ply and ./data/1742133879843/cloud_1006200.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1006200.ply and ./data/1742133879843/cloud_1006259.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1006259.ply and ./data/1742133879843/cloud_1006317.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1006317.ply and ./data/1742133879843/cloud_1006375.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1006375.ply and ./data/1742133879843/cloud_1006433.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1006433.ply and ./data/1742133879843/cloud_1006492.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1006492.ply and ./data/1742133879843/cloud_1006550.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1006550.ply and ./data/1742133879843/cloud_1006608.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1006608.ply and ./data/1742133879843/cloud_1006666.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1006725.ply and ./data/1742133879843/cloud_1006783.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1006783.ply and ./data/1742133879843/cloud_1006841.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1006841.ply and ./data/1742133879843/cloud_1006899.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1006899.ply and ./data/1742133879843/cloud_1006958.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1006958.ply and ./data/1742133879843/cloud_1007016.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1007016.ply and ./data/1742133879843/cloud_1007074.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1007074.ply and ./data/1742133879843/cloud_1007132.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1007132.ply and ./data/1742133879843/cloud_1007191.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1007191.ply and ./data/1742133879843/cloud_1007249.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1007249.ply and ./data/1742133879843/cloud_1007307.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1007307.ply and ./data/1742133879843/cloud_1007365.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1007365.ply and ./data/1742133879843/cloud_1007424.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1007424.ply and ./data/1742133879843/cloud_1007482.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1007482.ply and ./data/1742133879843/cloud_1007540.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1007540.ply and ./data/1742133879843/cloud_1007599.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1007599.ply and ./data/1742133879843/cloud_1007657.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1007657.ply and ./data/1742133879843/cloud_1007715.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1007715.ply and ./data/1742133879843/cloud_1007773.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1007773.ply and ./data/1742133879843/cloud_1007832.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1007832.ply and ./data/1742133879843/cloud_1007890.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1007890.ply and ./data/1742133879843/cloud_1007948.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1007948.ply and ./data/1742133879843/cloud_1008006.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1008006.ply and ./data/1742133879843/cloud_1008065.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1008065.ply and ./data/1742133879843/cloud_1008123.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1008123.ply and ./data/1742133879843/cloud_1008181.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1008181.ply and ./data/1742133879843/cloud_1008239.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1008239.ply and ./data/1742133879843/cloud_1008298.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1008298.ply and ./data/1742133879843/cloud_1008356.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1008356.ply and ./data/1742133879843/cloud_1008414.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1008414.ply and ./data/1742133879843/cloud_1008472.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1008472.ply and ./data/1742133879843/cloud_1008531.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1008531.ply and ./data/1742133879843/cloud_1008589.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1008589.ply and ./data/1742133879843/cloud_1008647.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1008647.ply and ./data/1742133879843/cloud_1008705.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1008705.ply and ./data/1742133879843/cloud_1008764.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1008764.ply and ./data/1742133879843/cloud_1008822.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1008822.ply and ./data/1742133879843/cloud_1008880.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1008880.ply and ./data/1742133879843/cloud_1008938.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1008938.ply and ./data/1742133879843/cloud_1008997.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1008997.ply and ./data/1742133879843/cloud_1009055.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1009055.ply and ./data/1742133879843/cloud_1009113.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1009113.ply and ./data/1742133879843/cloud_1009171.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1009171.ply and ./data/1742133879843/cloud_1009230.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1009230.ply and ./data/1742133879843/cloud_1009288.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1009288.ply and ./data/1742133879843/cloud_1009346.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1009346.ply and ./data/1742133879843/cloud_1009405.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1009405.ply and ./data/1742133879843/cloud_1009463.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1009463.ply and ./data/1742133879843/cloud_1009521.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1009521.ply and ./data/1742133879843/cloud_1009579.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1009579.ply and ./data/1742133879843/cloud_1009638.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1009638.ply and ./data/1742133879843/cloud_1009696.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1009696.ply and ./data/1742133879843/cloud_1009754.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1009754.ply and ./data/1742133879843/cloud_1009812.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1009812.ply and ./data/1742133879843/cloud_1009871.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1009871.ply and ./data/1742133879843/cloud_1009929.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1009929.ply and ./data/1742133879843/cloud_1009987.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1009987.ply and ./data/1742133879843/cloud_1010045.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1010045.ply and ./data/1742133879843/cloud_1010104.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1010104.ply and ./data/1742133879843/cloud_1010162.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1010162.ply and ./data/1742133879843/cloud_1010220.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1010220.ply and ./data/1742133879843/cloud_1010278.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1010278.ply and ./data/1742133879843/cloud_1010337.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1010337.ply and ./data/1742133879843/cloud_1010395.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1010395.ply and ./data/1742133879843/cloud_1010453.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1010453.ply and ./data/1742133879843/cloud_1010511.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1010511.ply and ./data/1742133879843/cloud_1010570.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1010570.ply and ./data/1742133879843/cloud_1010628.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1010628.ply and ./data/1742133879843/cloud_1010686.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1010686.ply and ./data/1742133879843/cloud_1010744.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1010803.ply and ./data/1742133879843/cloud_1010861.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1010861.ply and ./data/1742133879843/cloud_1010919.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1011094.ply and ./data/1742133879843/cloud_1011152.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1011152.ply and ./data/1742133879843/cloud_1011210.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1011269.ply and ./data/1742133879843/cloud_1011327.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1011327.ply and ./data/1742133879843/cloud_1011385.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1011444.ply and ./data/1742133879843/cloud_1011502.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1011560.ply and ./data/1742133879843/cloud_1011618.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1011618.ply and ./data/1742133879843/cloud_1011677.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1011677.ply and ./data/1742133879843/cloud_1011735.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1011735.ply and ./data/1742133879843/cloud_1011793.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1011793.ply and ./data/1742133879843/cloud_1011851.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1011851.ply and ./data/1742133879843/cloud_1011910.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1011910.ply and ./data/1742133879843/cloud_1011968.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1011968.ply and ./data/1742133879843/cloud_1012026.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1012026.ply and ./data/1742133879843/cloud_1012084.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1012084.ply and ./data/1742133879843/cloud_1012143.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1012143.ply and ./data/1742133879843/cloud_1012201.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1012201.ply and ./data/1742133879843/cloud_1012259.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1012259.ply and ./data/1742133879843/cloud_1012317.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1012317.ply and ./data/1742133879843/cloud_1012376.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1012550.ply and ./data/1742133879843/cloud_1012609.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1012609.ply and ./data/1742133879843/cloud_1012667.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1012783.ply and ./data/1742133879843/cloud_1012842.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1012842.ply and ./data/1742133879843/cloud_1012900.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1012900.ply and ./data/1742133879843/cloud_1012958.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1012958.ply and ./data/1742133879843/cloud_1013016.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1013133.ply and ./data/1742133879843/cloud_1013191.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1013191.ply and ./data/1742133879843/cloud_1013249.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1013249.ply and ./data/1742133879843/cloud_1013308.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1013308.ply and ./data/1742133879843/cloud_1013366.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1013424.ply and ./data/1742133879843/cloud_1013483.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1013483.ply and ./data/1742133879843/cloud_1013541.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1013541.ply and ./data/1742133879843/cloud_1013599.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1013599.ply and ./data/1742133879843/cloud_1013657.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1013657.ply and ./data/1742133879843/cloud_1013716.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1013716.ply and ./data/1742133879843/cloud_1013774.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1013774.ply and ./data/1742133879843/cloud_1013832.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1013832.ply and ./data/1742133879843/cloud_1013890.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1013890.ply and ./data/1742133879843/cloud_1013949.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1013949.ply and ./data/1742133879843/cloud_1014007.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1014007.ply and ./data/1742133879843/cloud_1014065.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1014065.ply and ./data/1742133879843/cloud_1014123.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1014123.ply and ./data/1742133879843/cloud_1014182.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1014182.ply and ./data/1742133879843/cloud_1014240.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1014240.ply and ./data/1742133879843/cloud_1014298.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1014298.ply and ./data/1742133879843/cloud_1014356.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1014356.ply and ./data/1742133879843/cloud_1014415.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1014415.ply and ./data/1742133879843/cloud_1014473.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1014473.ply and ./data/1742133879843/cloud_1014531.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1014531.ply and ./data/1742133879843/cloud_1014589.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1014589.ply and ./data/1742133879843/cloud_1014648.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1014648.ply and ./data/1742133879843/cloud_1014706.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1014706.ply and ./data/1742133879843/cloud_1014764.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1014764.ply and ./data/1742133879843/cloud_1014822.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1014822.ply and ./data/1742133879843/cloud_1014881.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1014881.ply and ./data/1742133879843/cloud_1014939.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1014939.ply and ./data/1742133879843/cloud_1014997.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1014997.ply and ./data/1742133879843/cloud_1015055.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1015055.ply and ./data/1742133879843/cloud_1015114.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1015114.ply and ./data/1742133879843/cloud_1015172.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1015172.ply and ./data/1742133879843/cloud_1015230.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1015230.ply and ./data/1742133879843/cloud_1015288.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1015288.ply and ./data/1742133879843/cloud_1015347.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1015347.ply and ./data/1742133879843/cloud_1015405.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1015405.ply and ./data/1742133879843/cloud_1015463.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1015463.ply and ./data/1742133879843/cloud_1015522.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1015522.ply and ./data/1742133879843/cloud_1015580.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1015580.ply and ./data/1742133879843/cloud_1015638.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1015638.ply and ./data/1742133879843/cloud_1015696.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1015696.ply and ./data/1742133879843/cloud_1015755.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1015755.ply and ./data/1742133879843/cloud_1015813.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1015813.ply and ./data/1742133879843/cloud_1015871.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1015871.ply and ./data/1742133879843/cloud_1015929.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1015929.ply and ./data/1742133879843/cloud_1015988.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1015988.ply and ./data/1742133879843/cloud_1016046.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1016046.ply and ./data/1742133879843/cloud_1016104.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1016104.ply and ./data/1742133879843/cloud_1016162.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1016162.ply and ./data/1742133879843/cloud_1016221.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1016221.ply and ./data/1742133879843/cloud_1016279.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1016279.ply and ./data/1742133879843/cloud_1016337.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1016337.ply and ./data/1742133879843/cloud_1016395.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1016395.ply and ./data/1742133879843/cloud_1016454.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1016454.ply and ./data/1742133879843/cloud_1016512.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1016512.ply and ./data/1742133879843/cloud_1016570.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1016570.ply and ./data/1742133879843/cloud_1016628.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1016628.ply and ./data/1742133879843/cloud_1016687.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1016687.ply and ./data/1742133879843/cloud_1016745.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1016745.ply and ./data/1742133879843/cloud_1016803.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1016803.ply and ./data/1742133879843/cloud_1016861.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1016861.ply and ./data/1742133879843/cloud_1016920.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1016920.ply and ./data/1742133879843/cloud_1016978.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1016978.ply and ./data/1742133879843/cloud_1017036.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1017094.ply and ./data/1742133879843/cloud_1017153.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1017153.ply and ./data/1742133879843/cloud_1017211.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1017211.ply and ./data/1742133879843/cloud_1017269.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1017269.ply and ./data/1742133879843/cloud_1017328.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1017328.ply and ./data/1742133879843/cloud_1017386.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1017386.ply and ./data/1742133879843/cloud_1017444.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1017444.ply and ./data/1742133879843/cloud_1017502.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1017502.ply and ./data/1742133879843/cloud_1017561.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1017561.ply and ./data/1742133879843/cloud_1017619.ply
# Warning: Different number of points between ./data/1742133879843/cloud_1017619.ply and ./data/1742133879843/cloud_1017677.ply
# ...
# Warning: Different number of points between ./data/1742134077274/cloud_1240747.ply and ./data/1742134077274/cloud_1240805.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1240805.ply and ./data/1742134077274/cloud_1240863.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1240863.ply and ./data/1742134077274/cloud_1240922.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1240922.ply and ./data/1742134077274/cloud_1240980.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1240980.ply and ./data/1742134077274/cloud_1241038.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1241038.ply and ./data/1742134077274/cloud_1241096.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1241096.ply and ./data/1742134077274/cloud_1241155.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1241213.ply and ./data/1742134077274/cloud_1241271.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1241271.ply and ./data/1742134077274/cloud_1241329.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1241329.ply and ./data/1742134077274/cloud_1241388.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1241388.ply and ./data/1742134077274/cloud_1241446.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1241446.ply and ./data/1742134077274/cloud_1241504.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1241504.ply and ./data/1742134077274/cloud_1241563.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1241563.ply and ./data/1742134077274/cloud_1241621.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1241621.ply and ./data/1742134077274/cloud_1241679.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1241679.ply and ./data/1742134077274/cloud_1241737.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1241796.ply and ./data/1742134077274/cloud_1241854.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1241854.ply and ./data/1742134077274/cloud_1241912.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1241912.ply and ./data/1742134077274/cloud_1241970.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1241970.ply and ./data/1742134077274/cloud_1242029.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1242029.ply and ./data/1742134077274/cloud_1242087.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1242087.ply and ./data/1742134077274/cloud_1242145.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1242145.ply and ./data/1742134077274/cloud_1242203.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1242262.ply and ./data/1742134077274/cloud_1242320.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1242320.ply and ./data/1742134077274/cloud_1242378.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1242378.ply and ./data/1742134077274/cloud_1242436.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1242436.ply and ./data/1742134077274/cloud_1242495.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1242495.ply and ./data/1742134077274/cloud_1242553.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1242553.ply and ./data/1742134077274/cloud_1242611.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1242611.ply and ./data/1742134077274/cloud_1242669.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1242669.ply and ./data/1742134077274/cloud_1242728.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1242728.ply and ./data/1742134077274/cloud_1242786.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1242786.ply and ./data/1742134077274/cloud_1242844.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1242844.ply and ./data/1742134077274/cloud_1242902.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1242902.ply and ./data/1742134077274/cloud_1242961.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1242961.ply and ./data/1742134077274/cloud_1243019.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1243077.ply and ./data/1742134077274/cloud_1243135.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1243135.ply and ./data/1742134077274/cloud_1243194.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1243194.ply and ./data/1742134077274/cloud_1243252.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1243252.ply and ./data/1742134077274/cloud_1243310.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1243310.ply and ./data/1742134077274/cloud_1243368.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1243368.ply and ./data/1742134077274/cloud_1243427.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1243427.ply and ./data/1742134077274/cloud_1243485.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1243485.ply and ./data/1742134077274/cloud_1243543.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1243602.ply and ./data/1742134077274/cloud_1243660.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1243660.ply and ./data/1742134077274/cloud_1243718.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1243718.ply and ./data/1742134077274/cloud_1243776.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1243776.ply and ./data/1742134077274/cloud_1243835.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1243893.ply and ./data/1742134077274/cloud_1243951.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1244009.ply and ./data/1742134077274/cloud_1244068.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1244068.ply and ./data/1742134077274/cloud_1244126.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1244126.ply and ./data/1742134077274/cloud_1244184.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1244184.ply and ./data/1742134077274/cloud_1244242.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1244242.ply and ./data/1742134077274/cloud_1244301.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1244359.ply and ./data/1742134077274/cloud_1244417.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1244417.ply and ./data/1742134077274/cloud_1244475.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1244475.ply and ./data/1742134077274/cloud_1244534.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1244534.ply and ./data/1742134077274/cloud_1244592.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1244650.ply and ./data/1742134077274/cloud_1244708.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1244708.ply and ./data/1742134077274/cloud_1244767.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1244767.ply and ./data/1742134077274/cloud_1244825.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1244825.ply and ./data/1742134077274/cloud_1244883.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1244883.ply and ./data/1742134077274/cloud_1244941.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1244941.ply and ./data/1742134077274/cloud_1245000.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1245000.ply and ./data/1742134077274/cloud_1245058.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1245058.ply and ./data/1742134077274/cloud_1245116.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1245116.ply and ./data/1742134077274/cloud_1245174.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1245174.ply and ./data/1742134077274/cloud_1245233.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1245233.ply and ./data/1742134077274/cloud_1245291.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1245291.ply and ./data/1742134077274/cloud_1245349.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1245349.ply and ./data/1742134077274/cloud_1245408.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1245408.ply and ./data/1742134077274/cloud_1245466.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1245466.ply and ./data/1742134077274/cloud_1245524.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1245524.ply and ./data/1742134077274/cloud_1245582.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1245641.ply and ./data/1742134077274/cloud_1245699.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1245699.ply and ./data/1742134077274/cloud_1245757.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1245757.ply and ./data/1742134077274/cloud_1245815.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1245815.ply and ./data/1742134077274/cloud_1245874.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1245874.ply and ./data/1742134077274/cloud_1245932.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1245932.ply and ./data/1742134077274/cloud_1245990.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1245990.ply and ./data/1742134077274/cloud_1246048.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1246048.ply and ./data/1742134077274/cloud_1246107.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1246107.ply and ./data/1742134077274/cloud_1246165.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1246165.ply and ./data/1742134077274/cloud_1246223.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1246223.ply and ./data/1742134077274/cloud_1246281.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1246281.ply and ./data/1742134077274/cloud_1246340.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1246340.ply and ./data/1742134077274/cloud_1246398.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1246398.ply and ./data/1742134077274/cloud_1246456.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1246456.ply and ./data/1742134077274/cloud_1246514.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1246514.ply and ./data/1742134077274/cloud_1246573.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1246573.ply and ./data/1742134077274/cloud_1246631.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1246631.ply and ./data/1742134077274/cloud_1246689.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1246689.ply and ./data/1742134077274/cloud_1246747.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1246747.ply and ./data/1742134077274/cloud_1246806.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1246864.ply and ./data/1742134077274/cloud_1246922.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1246922.ply and ./data/1742134077274/cloud_1246980.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1246980.ply and ./data/1742134077274/cloud_1247039.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1247097.ply and ./data/1742134077274/cloud_1247155.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1247155.ply and ./data/1742134077274/cloud_1247213.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1247213.ply and ./data/1742134077274/cloud_1247272.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1247272.ply and ./data/1742134077274/cloud_1247330.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1247330.ply and ./data/1742134077274/cloud_1247388.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1247388.ply and ./data/1742134077274/cloud_1247447.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1247447.ply and ./data/1742134077274/cloud_1247505.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1247505.ply and ./data/1742134077274/cloud_1247563.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1247563.ply and ./data/1742134077274/cloud_1247621.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1247621.ply and ./data/1742134077274/cloud_1247680.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1247680.ply and ./data/1742134077274/cloud_1247738.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1247738.ply and ./data/1742134077274/cloud_1247796.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1247796.ply and ./data/1742134077274/cloud_1247854.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1247854.ply and ./data/1742134077274/cloud_1247913.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1247913.ply and ./data/1742134077274/cloud_1247971.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1247971.ply and ./data/1742134077274/cloud_1248029.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1248029.ply and ./data/1742134077274/cloud_1248087.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1248087.ply and ./data/1742134077274/cloud_1248146.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1248146.ply and ./data/1742134077274/cloud_1248204.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1248204.ply and ./data/1742134077274/cloud_1248262.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1248262.ply and ./data/1742134077274/cloud_1248320.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1248320.ply and ./data/1742134077274/cloud_1248379.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1248379.ply and ./data/1742134077274/cloud_1248437.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1248437.ply and ./data/1742134077274/cloud_1248495.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1248495.ply and ./data/1742134077274/cloud_1248553.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1248553.ply and ./data/1742134077274/cloud_1248612.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1248612.ply and ./data/1742134077274/cloud_1248670.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1248670.ply and ./data/1742134077274/cloud_1248728.ply
# Warning: Different number of points between ./data/1742134077274/cloud_1248786.ply and ./data/1742134077274/cloud_1248845.ply

# %% [markdown]
# **Explanation**:
# - We show how you might put everything together:
#   1. Use `get_ply_file_paths` to gather PLY file paths.
#   2. Use `sliding_window_ply_files` with a `window_size=100` to process them in manageable batches.
#   3. For each chunk, run `compute_pointcloud_deltas` to get the DataFrames for frames and their deltas.
#   4. We provide an example of plotting `delta_x` for the *first point* across consecutive frames in the chunk.
#   5. You could similarly look at any point (index) or even compute aggregate statistics (like the mean delta across all points).

# %% [markdown]
# # Conclusion
#
# This notebook demonstrates a basic pipeline to:
# 1. **Load** ASCII-based PLY files (or via `open3d`).
# 2. **Construct** a Pandas DataFrame for each point cloud.
# 3. **Compute** simple frame-to-frame deltas (differences) for each coordinate.
# 4. **Plot** a sample time series of these differences.
#
# In practice, you may need more advanced methods to:
# - Align or register consecutive frames (when the number of points or ordering changes).
# - Use 3D transformations to track the object of interest (e.g., the beating heart surface).
# - Subsample or filter noisy points.
#
# Nevertheless, this approach provides a starting framework for analyzing changes over time in a sequence of PLY point clouds.
